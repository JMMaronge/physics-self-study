# %% [markdown]
# # Chapter 1 — Newton's Laws of Motion — Explorations
#
# One notebook, one chapter. Add experiments only when they answer a physical question.

# %% [markdown]
# ## 1. Question
#
# State one focused physical question.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %% [markdown]
# ## 2. Physical model
#
# Write the assumptions, governing equations, parameters, and initial conditions.

# %%
g = 9.81
time = 2.0

distance = 0.5 * g * time**2

print(distance)
# Out:
# 19.62

# %% [markdown]
# ## 3. Analytical benchmark
#
# Identify a special case or exact result the code should reproduce.

# %% [markdown]
# ## 4. Numerical implementation

# %%
# Implement the model here.

# %% [markdown]
# ## 5. Validation
#
# - Units
# - Initial conditions
# - Limiting case
# - Step-size or tolerance sensitivity

# %% [markdown]
# ## 6. Interpretation
#
# Explain what the result teaches you about the physics.
